# %%
# Installing the necessary packages
# !pip install pandas

# %%
# Importing the packages
import pandas as pd

# %%
# Importing the data
df = pd.read_csv("../Scraper/data.csv")
df.head()
# Out:
#    price_total_1  price_total_2  price_total_3  Area (sq m)  area_type_id  \
# 0         269418          97000          89252         75.0             1
# 1         555500         200000         184026         67.0             1
# 2         277750         100000          92013         55.0             1
# 3         269279          96950          89206         64.0             1
# 4         486063         175000         161022        102.0             1
#
#    price_square_1  price_square_2  price_square_3 owner_name  \
# 0            3592            1293            1190       მაია
# 1            8291            2985            2747     გიორგი
# 2            5050            1818            1673     გიორგი
# 3            4207            1515            1394   ნიკოლოზი
# 4            4765            1716            1579      Natia
#
#   user_phone_number  ...  balconies balcony_area storeroom_type_id  \
# 0         577151***  ...        1.0         76.0               NaN
# ...
